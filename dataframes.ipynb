# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehhhhull/pandas/blob/main/dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Combining Multiple Series together is called data frames.**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Creating a DataFrame

# %%
data={
    'Name':['John','Anna','Peter','Linda'],
    'Age':[28,34,55,42],
    'City':['New York','Paris','Berlin','London'],
    'Salary':[65000,70000,62000,85000]

}

df=pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   55    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list=[
    ['John',28,'New York',65000],
    ['Anna',34,'Paris',75000],
    ['Peter',29,'Berlin',62000],
    ['Linda',42,'London',5000],
]
df2=pd.DataFrame(data_list)
columns=['Name','Age','City','Salary']
df2=pd.DataFrame(data_list,columns=columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   75000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London    5000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   75000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London    5000

# %% [markdown]
# **Selection and indexing of columns**

# %%
df2['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df2[['Name','City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# **Creating a new column**

# %%
df2["Designation"]=["Doctor","Eng.","Doctor","Eng."]
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   75000        Eng.
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London    5000        Eng.

# %% [markdown]
# **Removing a column**

# %%
df2.drop('Designation',axis=1,inplace=True)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   75000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London    5000

# %% [markdown]
# **Selecting Rows**

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   75000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London    5000

# %%
df2.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %% [markdown]
# **Selecting subsets of rows and columns**

# %%
df2.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   75000

# %% [markdown]
# **Conditional Selection**

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   75000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London    5000

# %%
#i only want to see whose age is above than 30

# %%
df2[df2["Age"]>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   75000
# 3  Linda   42  London    5000

# %%
#only want people above 30 and city must be paris

# %%
df2
df2[(df2["Age"]>30) & (df2["City"]=="Paris")]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   75000
